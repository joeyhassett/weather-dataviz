# %%
import requests
from pprint import pprint

## getting lat/long from address through api call
address = "385 Blackwood Lane Suwanee, GA 30024"
loc_apikey = "aOgwwD7ajrzcnfTx3pJKPfpjL0HvSgzA"
url_loc = f"https://api.tomtom.com/search/2/geocode/{address}.json?key={loc_apikey}"
loc = requests.get(url_loc)
loc = loc.json()


## getting weather info through api call
weather_apikey = "ba51b863eb7227d65109a950334684bd"
lat = loc["results"][0]["entryPoints"][0]["position"]["lat"]
lon = loc["results"][0]["entryPoints"][0]["position"]["lon"
url_weather = f"https://api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={16}&appid={weather_apikey}"
weather = requests.get(url_weather)
weather = weather.json()
pprint(data)

# for day in range(16):
#     print(data["data"][day]["app_max_temp"])
# Out:
# -84.12533
# {'city_name': 'Saga',
#  'country_code': 'CN',
#  'data': [{'app_max_temp': -3.9,
#            'app_min_temp': -9.8,
#            'clouds': 68,
#            'clouds_hi': 68,
#            'clouds_low': 0,
#            'clouds_mid': 68,
#            'datetime': '2023-04-09',
#            'dewpt': -27.9,
#            'high_temp': 1.4,
#            'low_temp': -7.4,
#            'max_dhi': None,
#            'max_temp': 1.2,
#            'min_temp': -6.8,
#            'moon_phase': 0.911019,
#            'moon_phase_lunation': 0.62,
#            'moonrise_ts': 1681052738,
#            'moonset_ts': 1681004191,
#            'ozone': 275.2,
#            'pop': 25,
#            'precip': 0.4375,
#            'pres': 566.6,
#            'rh': 13,
#            'slp': 1017.3,
#            'snow': 1.5,
#            'snow_depth': 0.2,
#            'sunrise_ts': 1680998241,
#            'sunset_ts': 1681044395,
#            'temp': -2.7,
#            'ts': 1680969660,
#            'uv': 6,
#            'valid_date': '2023-04-09',
#            'vis': 21.063,
#            'weather': {'code': 511,
#                        'description': 'Freezing rain',
#                        'icon': 'f01d'},
#            'wind_cdir': 'SW',
#            'wind_cdir_full': 'southwest',
#            'wind_dir': 231,
#            'wind_gust_spd': 4.4,
#            'wind_spd': 4},
#           {'app_max_temp': -2.9,
#            'app_min_temp': -13.4,
#            'clouds': 78,
#            'clouds_hi': 69,
#            'clouds_low': 0,
#            'clouds_mid': 76,
#            'datetime': '2023-04-10',
#            'dewpt': -27.2,
#            'high_temp': 2.2,
#            'low_temp': -5.8,
#            'max_dhi': None,
#            'max_temp': 2.1,
#            'min_temp': -7.6,
#            'moon_phase': 0.837663,
#            'moon_phase_lunation': 0.65,
#            'moonrise_ts': 1681056780,
#            'moonset_ts': 1681093002,
#            'ozone': 266.1,
#            'pop': 40,
#            'precip': 0.625,
#            'pres': 565.8,
#            'rh': 14,
#            'slp': 1016.2,
#            'snow': 3.0625,
#            'snow_depth': 3.3,
#            'sunrise_ts': 1681084563,
#            'sunset_ts': 1681130841,
#            'temp': -2.9,
#            'ts': 1681056060,
#            'uv': 3,
#            'valid_date': '2023-04-10',
#            'vis': 20.126,
#            'weather': {'code': 610,
#                        'description': 'Mix snow/rain',
#                        'icon': 's04d'},
#            'wind_cdir': 'SSE',
#            'wind_cdir_full': 'south-southeast',
#            'wind_dir': 165,
#            'wind_gust_spd': 6.3,
#            'wind_spd': 4.9},
#           {'app_max_temp': -4.2,
#            'app_min_temp': -11.2,
#            'clouds': 71,
#            'clouds_hi': 82,
#            'clouds_low': 0,
#            'clouds_mid': 70,
#            'datetime': '2023-04-11',
#            'dewpt': -25.8,
#            'high_temp': 1.6,
#            'low_temp': -6.3,
#            'max_dhi': None,
#            'max_temp': 1.5,
#            'min_temp': -6.4,
#            'moon_phase': 0.745333,
#            'moon_phase_lunation': 0.69,
#            'moonrise_ts': 1681147279,
#            'moonset_ts': 1681182307,
#            'ozone': 275.9,
#            'pop': 35,
#            'precip': 0.6875,
#            'pres': 565.2,
#            'rh': 15,
#            'slp': 1014.1,
#            'snow': 2.1875,
#            'snow_depth': 5.5,
#            'sunrise_ts': 1681170886,
#            'sunset_ts': 1681217287,
#            'temp': -2.1,
#            'ts': 1681142460,
#            'uv': 4,
#            'valid_date': '2023-04-11',
#            'vis': 19.469,
#            'weather': {'code': 610,
#                        'description': 'Mix snow/rain',
#                        'icon': 's04d'},
#            'wind_cdir': 'SW',
#            'wind_cdir_full': 'southwest',
#            'wind_dir': 222,
#            'wind_gust_spd': 5.7,
#            'wind_spd': 4.4},
#           {'app_max_temp': -3.2,
#            'app_min_temp': -11.9,
#            'clouds': 26,
#            'clouds_hi': 48,
#            'clouds_low': 0,
#            'clouds_mid': 22,
#            'datetime': '2023-04-12',
#            'dewpt': -26.6,
#            'high_temp': 2.1,
#            'low_temp': -4.8,
#            'max_dhi': None,
#            'max_temp': 2,
#            'min_temp': -6.9,
#            'moon_phase': 0.637867,
#            'moon_phase_lunation': 0.72,
#            'moonrise_ts': 1681237650,
#            'moonset_ts': 1681272161,
#            'ozone': 285.6,
#            'pop': 15,
#            'precip': 0.25,
#            'pres': 566.1,
#            'rh': 15,
#            'slp': 1015.7,
#            'snow': 0.4375,
#            'snow_depth': 5.9,
#            'sunrise_ts': 1681257208,
#            'sunset_ts': 1681303732,
#            'temp': -1.9,
#            'ts': 1681228860,
#            'uv': 9.4,
#            'valid_date': '2023-04-12',
#            'vis': 23.023,
#            'weather': {'code': 610,
#                        'description': 'Mix snow/rain',
#                        'icon': 's04d'},
#            'wind_cdir': 'WNW',
#            'wind_cdir_full': 'west-northwest',
#            'wind_dir': 283,
#            'wind_gust_spd': 7.5,
#            'wind_spd': 5.2},
#           {'app_max_temp': -6.5,
#            'app_min_temp': -12.3,
#            'clouds': 31,
#            'clouds_hi': 59,
#            'clouds_low': 0,
#            'clouds_mid': 25,
#            'datetime': '2023-04-13',
#            'dewpt': -23.9,
#            'high_temp': 1,
#            'low_temp': -7.3,
#            'max_dhi': None,
#            'max_temp': 0.8,
#            'min_temp': -5.2,
#            'moon_phase': 0.520634,
#            'moon_phase_lunation': 0.76,
#            'moonrise_ts': 1681327684,
#            'moonset_ts': 1681362500,
#            'ozone': 300.9,
#            'pop': 45,
#            'precip': 0.875,
#            'pres': 567.1,
#            'rh': 19,
#            'slp': 1018.2,
#            'snow': 0,
#            'snow_depth': 5.9,
#            'sunrise_ts': 1681343532,
#            'sunset_ts': 1681390178,
#            'temp': -2.8,
#            'ts': 1681315260,
#            'uv': 9.9,
#            'valid_date': '2023-04-13',
#            'vis': 20.802,
#            'weather': {'code': 511,
#                        'description': 'Freezing rain',
#                        'icon': 'f01d'},
#            'wind_cdir': 'NW',
#            'wind_cdir_full': 'northwest',
#            'wind_dir': 305,
#            'wind_gust_spd': 9.4,
#            'wind_spd': 7.2},
#           {'app_max_temp': -1.8,
#            'app_min_temp': -10.3,
#            'clouds': 20,
#            'clouds_hi': 29,
#            'clouds_low': 0,
#            'clouds_mid': 17,
#            'datetime': '2023-04-14',
#            'dewpt': -26.1,
#            'high_temp': 1.4,
#            'low_temp': -5,
#            'max_dhi': None,
#            'max_temp': 1.4,
#            'min_temp': -8.3,
#            'moon_phase': 0.400409,
#            'moon_phase_lunation': 0.79,
#            'moonrise_ts': 1681417242,
#            'moonset_ts': 1681453142,
#            'ozone': 319.6,
#            'pop': 20,
#            'precip': 0.0625,
#            'pres': 571.7,
#            'rh': 17,
#            'slp': 1026.4,
#            'snow': 0,
#            'snow_depth': 5.9,
#            'sunrise_ts': 1681429856,
#            'sunset_ts': 1681476624,
#            'temp': -3.1,
#            'ts': 1681401660,
#            'uv': 10,
#            'valid_date': '2023-04-14',
#            'vis': 24.126,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_cdir': 'SSW',
#            'wind_cdir_full': 'south-southwest',
#            'wind_dir': 193,
#            'wind_gust_spd': 3.1,
#            'wind_spd': 2.1},
#           {'app_max_temp': 2.1,
#            'app_min_temp': -10.4,
#            'clouds': 29,
#            'clouds_hi': 38,
#            'clouds_low': 0,
#            'clouds_mid': 26,
#            'datetime': '2023-04-15',
#            'dewpt': -21.8,
#            'high_temp': 4.8,
#            'low_temp': -0.9,
#            'max_dhi': None,
#            'max_temp': 4.5,
#            'min_temp': -6,
#            'moon_phase': 0.28483,
#            'moon_phase_lunation': 0.82,
#            'moonrise_ts': 1681506314,
#            'moonset_ts': 1681543876,
#            'ozone': 313.8,
#            'pop': 0,
#            'precip': 0,
#            'pres': 571.7,
#            'rh': 19,
#            'slp': 1023.7,
#            'snow': 0,
#            'snow_depth': 5.9,
#            'sunrise_ts': 1681516180,
#            'sunset_ts': 1681563070,
#            'temp': -0.3,
#            'ts': 1681488060,
#            'uv': 10,
#            'valid_date': '2023-04-15',
#            'vis': 24.128,
#            'weather': {'code': 802,
#                        'description': 'Scattered clouds',
#                        'icon': 'c02d'},
#            'wind_cdir': 'E',
#            'wind_cdir_full': 'east',
#            'wind_dir': 99,
#            'wind_gust_spd': 4.6,
#            'wind_spd': 3.3},
#           {'app_max_temp': 0.1,
#            'app_min_temp': -6.6,
#            'clouds': 61,
#            'clouds_hi': 98,
#            'clouds_low': 0,
#            'clouds_mid': 50,
#            'datetime': '2023-04-16',
#            'dewpt': -14.6,
#            'high_temp': 5.6,
#            'low_temp': -2.4,
#            'max_dhi': None,
#            'max_temp': 5,
#            'min_temp': -1.3,
#            'moon_phase': 0.181568,
#            'moon_phase_lunation': 0.86,
#            'moonrise_ts': 1681594981,
#            'moonset_ts': 1681634551,
#            'ozone': 301.2,
#            'pop': 25,
#            'precip': 0.375,
#            'pres': 567,
#            'rh': 32,
#            'slp': 1012.9,
#            'snow': 1.5,
#            'snow_depth': 7.4,
#            'sunrise_ts': 1681602506,
#            'sunset_ts': 1681649516,
#            'temp': 2,
#            'ts': 1681574460,
#            'uv': 10.1,
#            'valid_date': '2023-04-16',
#            'vis': 21.997,
#            'weather': {'code': 511,
#                        'description': 'Freezing rain',
#                        'icon': 'f01d'},
#            'wind_cdir': 'SW',
#            'wind_cdir_full': 'southwest',
#            'wind_dir': 225,
#            'wind_gust_spd': 8.1,
#            'wind_spd': 6.3},
#           {'app_max_temp': 4.1,
#            'app_min_temp': -7.7,
#            'clouds': 9,
#            'clouds_hi': 28,
#            'clouds_low': 0,
#            'clouds_mid': 3,
#            'datetime': '2023-04-17',
#            'dewpt': -21.1,
#            'high_temp': 7.2,
#            'low_temp': 0.1,
#            'max_dhi': None,
#            'max_temp': 7,
#            'min_temp': -3.8,
#            'moon_phase': 0.0974682,
#            'moon_phase_lunation': 0.89,
#            'moonrise_ts': 1681683359,
#            'moonset_ts': 1681725116,
#            'ozone': 281.2,
#            'pop': 0,
#            'precip': 0,
#            'pres': 566.1,
#            'rh': 21,
#            'slp': 1011.4,
#            'snow': 0,
#            'snow_depth': 7.4,
#            'sunrise_ts': 1681688831,
#            'sunset_ts': 1681735962,
#            'temp': 1.9,
#            'ts': 1681660860,
#            'uv': 10.1,
#            'valid_date': '2023-04-17',
#            'vis': 24.128,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_cdir': 'WSW',
#            'wind_cdir_full': 'west-southwest',
#            'wind_dir': 253,
#            'wind_gust_spd': 5.9,
#            'wind_spd': 4.8},
#           {'app_max_temp': 1.6,
#            'app_min_temp': -6.2,
#            'clouds': 37,
#            'clouds_hi': 87,
#            'clouds_low': 0,
#            'clouds_mid': 20,
#            'datetime': '2023-04-18',
#            'dewpt': -18,
#            'high_temp': 6.7,
#            'low_temp': 1.2,
#            'max_dhi': None,
#            'max_temp': 6.3,
#            'min_temp': -2.1,
#            'moon_phase': 0.0377964,
#            'moon_phase_lunation': 0.93,
#            'moonrise_ts': 1681771563,
#            'moonset_ts': 1681815584,
#            'ozone': 283,
#            'pop': 0,
#            'precip': 0,
#            'pres': 568,
#            'rh': 23,
#            'slp': 1014.8,
#            'snow': 0,
#            'snow_depth': 7.4,
#            'sunrise_ts': 1681775158,
#            'sunset_ts': 1681822408,
#            'temp': 1.8,
#            'ts': 1681747260,
#            'uv': 10.2,
#            'valid_date': '2023-04-18',
#            'vis': 24.128,
#            'weather': {'code': 802,
#                        'description': 'Scattered clouds',
#                        'icon': 'c02d'},
#            'wind_cdir': 'SW',
#            'wind_cdir_full': 'southwest',
#            'wind_dir': 220,
#            'wind_gust_spd': 5,
#            'wind_spd': 4.7},
#           {'app_max_temp': 2.7,
#            'app_min_temp': -1.6,
#            'clouds': 28,
#            'clouds_hi': 22,
#            'clouds_low': 0,
#            'clouds_mid': 27,
#            'datetime': '2023-04-19',
#            'dewpt': -19.9,
#            'high_temp': 7.8,
#            'low_temp': 2.7,
#            'max_dhi': None,
#            'max_temp': 7,
#            'min_temp': 1.2,
#            'moon_phase': 0.00567481,
#            'moon_phase_lunation': 0.96,
#            'moonrise_ts': 1681859697,
#            'moonset_ts': 1681906000,
#            'ozone': 276.3,
#            'pop': 10,
#            'precip': 0.1875,
#            'pres': 570,
#            'rh': 16,
#            'slp': 1016,
#            'snow': 0,
#            'snow_depth': 5.7,
#            'sunrise_ts': 1681861485,
#            'sunset_ts': 1681908854,
#            'temp': 4.1,
#            'ts': 1681833660,
#            'uv': 10.2,
#            'valid_date': '2023-04-19',
#            'vis': 24.128,
#            'weather': {'code': 802,
#                        'description': 'Scattered clouds',
#                        'icon': 'c02d'},
#            'wind_cdir': 'WSW',
#            'wind_cdir_full': 'west-southwest',
#            'wind_dir': 252,
#            'wind_gust_spd': 5.7,
#            'wind_spd': 5.3},
#           {'app_max_temp': 7.9,
#            'app_min_temp': -1.7,
#            'clouds': 45,
#            'clouds_hi': 47,
#            'clouds_low': 0,
#            'clouds_mid': 45,
#            'datetime': '2023-04-20',
#            'dewpt': -18.7,
#            'high_temp': 8,
#            'low_temp': 2,
#            'max_dhi': None,
#            'max_temp': 7.9,
#            'min_temp': 2.7,
#            'moon_phase': 0.00182383,
#            'moon_phase_lunation': 0.99,
#            'moonrise_ts': 1681947853,
#            'moonset_ts': 1681996405,
#            'ozone': 261.3,
#            'pop': 0,
#            'precip': 0,
#            'pres': 567.8,
#            'rh': 16,
#            'slp': 1011.3,
#            'snow': 0,
#            'snow_depth': 2.6,
#            'sunrise_ts': 1681947813,
#            'sunset_ts': 1681995301,
#            'temp': 5.3,
#            'ts': 1681920060,
#            'uv': 10.3,
#            'valid_date': '2023-04-20',
#            'vis': 24.128,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03d'},
#            'wind_cdir': 'WSW',
#            'wind_cdir_full': 'west-southwest',
#            'wind_dir': 237,
#            'wind_gust_spd': 11.3,
#            'wind_spd': 8},
#           {'app_max_temp': 1.8,
#            'app_min_temp': -3.8,
#            'clouds': 7,
#            'clouds_hi': 1,
#            'clouds_low': 0,
#            'clouds_mid': 7,
#            'datetime': '2023-04-21',
#            'dewpt': -19,
#            'high_temp': 7.1,
#            'low_temp': 2.4,
#            'max_dhi': None,
#            'max_temp': 7,
#            'min_temp': 2,
#            'moon_phase': 0.0246901,
#            'moon_phase_lunation': 0.03,
#            'moonrise_ts': 1682034253,
#            'moonset_ts': 1682086810,
#            'ozone': 256.4,
#            'pop': 20,
#            'precip': 0.0625,
#            'pres': 565.8,
#            'rh': 17,
#            'slp': 1008.5,
#            'snow': 0,
#            'snow_depth': 1.6,
#            'sunrise_ts': 1682034142,
#            'sunset_ts': 1682081747,
#            'temp': 4.5,
#            'ts': 1682006460,
#            'uv': 10.3,
#            'valid_date': '2023-04-21',
#            'vis': 24.128,
#            'weather': {'code': 801,
#                        'description': 'Few clouds',
#                        'icon': 'c02d'},
#            'wind_cdir': 'WSW',
#            'wind_cdir_full': 'west-southwest',
#            'wind_dir': 251,
#            'wind_gust_spd': 14.4,
#            'wind_spd': 10.2},
#           {'app_max_temp': 1.2,
#            'app_min_temp': -4.1,
#            'clouds': 62,
#            'clouds_hi': 97,
#            'clouds_low': 0,
#            'clouds_mid': 52,
#            'datetime': '2023-04-22',
#            'dewpt': -17.6,
#            'high_temp': 6.7,
#            'low_temp': 0.8,
#            'max_dhi': None,
#            'max_temp': 6.6,
#            'min_temp': 2.4,
#            'moon_phase': 0.0709293,
#            'moon_phase_lunation': 0.06,
#            'moonrise_ts': 1682122522,
#            'moonset_ts': 1682177176,
#            'ozone': 262.4,
#            'pop': 20,
#            'precip': 0.125,
#            'pres': 563.8,
#            'rh': 19,
#            'slp': 1005,
#            'snow': 0,
#            'snow_depth': 0.8,
#            'sunrise_ts': 1682120471,
#            'sunset_ts': 1682168194,
#            'temp': 4.5,
#            'ts': 1682092860,
#            'uv': 10.3,
#            'valid_date': '2023-04-22',
#            'vis': 24.128,
#            'weather': {'code': 803,
#                        'description': 'Broken clouds',
#                        'icon': 'c03d'},
#            'wind_cdir': 'SW',
#            'wind_cdir_full': 'southwest',
#            'wind_dir': 234,
#            'wind_gust_spd': 16.2,
#            'wind_spd': 11.5},
#           {'app_max_temp': -4.4,
#            'app_min_temp': -7.3,
#            'clouds': 63,
#            'clouds_hi': 100,
#            'clouds_low': 0,
#            'clouds_mid': 54,
#            'datetime': '2023-04-23',
#            'dewpt': -13.5,
#            'high_temp': 0.8,
#            'low_temp': -4,
#            'max_dhi': None,
#            'max_temp': 0.8,
#            'min_temp': -4,
#            'moon_phase': 0.136104,
#            'moon_phase_lunation': 0.1,
#            'moonrise_ts': 1682210989,
#            'moonset_ts': 1682181006,
#            'ozone': 277.5,
#            'pop': 95,
#            'precip': 5.3125,
#            'pres': 563.5,
#            'rh': 43,
#            'slp': 1008.8,
#            'snow': 60,
#            'snow_depth': 60.8,
#            'sunrise_ts': 1682206802,
#            'sunset_ts': 1682254640,
#            'temp': -1.6,
#            'ts': 1682179260,
#            'uv': 10.4,
#            'valid_date': '2023-04-23',
#            'vis': 24.128,
#            'weather': {'code': 601, 'description': 'Snow', 'icon': 's02d'},
#            'wind_cdir': 'NW',
#            'wind_cdir_full': 'northwest',
#            'wind_dir': 311,
#            'wind_gust_spd': 5.5,
#            'wind_spd': 3.9},
#           {'app_max_temp': -3.2,
#            'app_min_temp': -7.3,
#            'clouds': 70,
#            'clouds_hi': 84,
#            'clouds_low': 0,
#            'clouds_mid': 70,
#            'datetime': '2023-04-24',
#            'dewpt': -11.6,
#            'high_temp': 1.3,
#            'low_temp': 1.2,
#            'max_dhi': None,
#            'max_temp': 1.2,
#            'min_temp': -2.7,
#            'moon_phase': 0.215418,
#            'moon_phase_lunation': 0.13,
#            'moonrise_ts': 1682299734,
#            'moonset_ts': 1682270974,
#            'ozone': 278.3,
#            'pop': 65,
#            'precip': 2.6875,
#            'pres': 565.8,
#            'rh': 47,
#            'slp': 1013.5,
#            'snow': 3.5,
#            'snow_depth': 64.3,
#            'sunrise_ts': 1682293133,
#            'sunset_ts': 1682341087,
#            'temp': -0.8,
#            'ts': 1682265660,
#            'uv': 10.4,
#            'valid_date': '2023-04-24',
#            'vis': 14.044,
#            'weather': {'code': 610,
#                        'description': 'Mix snow/rain',
#                        'icon': 's04d'},
#            'wind_cdir': 'SSE',
#            'wind_cdir_full': 'south-southeast',
#            'wind_dir': 153,
#            'wind_gust_spd': 6,
#            'wind_spd': 4.1}],
#  'lat': 33.7885,
#  'lon': 84.372,
#  'state_code': '14',
#  'timezone': 'Asia/Shanghai'}
